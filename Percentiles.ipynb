# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vals = np.random.normal(0, 2, 10_000)
plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# -0.02783617066502902

# %%
np.percentile(vals, 90)
# Out:
# 2.5715644538575817

# %%
np.percentile(vals, 20)
# Out:
# -1.75082599462116
