# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
vals = np.random.normal(10_000, 100_000, 10_000)
plt.hist(vals, 50)
plt.show()

# %%
np.percentile(vals, 50)
# Out:
# 9947.838242620348

# %%
np.percentile(vals, 90)
# Out:
# 136888.19202022318

# %%
np.percentile(vals, 20)
# Out:
# -75563.51000507273
